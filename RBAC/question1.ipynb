# %%
# generate data
# list of points
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.distance import cdist
import pandas as pd
np.random.seed(2)

# %%
loan_approval = pd.read_csv("loan_approval.csv")
loan_approval[["cibil_score", "loan_status"]].head(10)
# Out:
#    cibil_score loan_status
# 0          778    Approved
# 1          417    Rejected
# 2          506    Rejected
# 3          382    Rejected
# 4          678    Approved
# 5          382    Rejected
# 6          782    Approved
# 7          388    Rejected
# 8          547    Approved
# 9          538    Rejected

# %%
X = loan_approval[["cibil_score"]].to_numpy()
y = loan_approval[["loan_status"]].to_numpy()

Y = []

for i in y:
    Y.append(str(i)=="Approved")

Y
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...
